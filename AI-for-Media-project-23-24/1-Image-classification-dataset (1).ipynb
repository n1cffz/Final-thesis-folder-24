# %% [markdown]
# # 1. Classification dataset #
# The following code shows how I created new files for each emotion classifer and extracted images from Pinterest through an iterative process.
# This code does not need to be re-run because the data has already been sectioned and labelled in 'my-classification-dataset' for ease of use.
# Code adapted from: https://git.arts.ac.uk/tbroad/AI-4-Media-23-24/blob/main/Week-3-CNNs-and-image-classification/create-classification-dataset.ipynb.

# %%
import os
import shutil
import subprocess

# may require the following install within terminal: pip install gallery-dl

# %%
# Make a directory for the dowloaded datasets
my_dataset_path = 'my-classification-dataset'
os.mkdir(my_dataset_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /Users/nixi/Desktop/Final thesis folder 24/AI-for-Media-project-23-24/1-Image-classification-dataset (1).ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/Users/nixi/Desktop/Final%20thesis%20folder%2024/AI-for-Media-project-23-24/1-Image-classification-dataset%20%281%29.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Make a directory for the dowloaded datasets
#       <a href='vscode-notebook-cell:/Users/nixi/Desktop/Final%20thesis%20folder%2024/AI-for-Media-project-23-24/1-Image-classification-dataset%20%281%29.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> my_dataset_path = 'my-classification-dataset'
# ----> <a href='vscode-notebook-cell:/Users/nixi/Desktop/Final%20thesis%20folder%2024/AI-for-Media-project-23-24/1-Image-classification-dataset%20%281%29.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> os.mkdir(my_dataset_path)
#
# ...

# %%
# Subfolders for each emotional class within dataset

os.mkdir( os.path.join(my_dataset_path, 'neutral-face') )
os.mkdir( os.path.join(my_dataset_path, 'happy-face') )
os.mkdir( os.path.join(my_dataset_path, 'sad-face') )
os.mkdir( os.path.join(my_dataset_path, 'angry-face') )

# %%
# create a open file for the Pinterest data to be dowloaded into each class iteration 
os.mkdir('gallery-dl')

# %%
pip install gallery-dl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 590 kB 1.5 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Neutral faces

# %%
import subprocess

# 'Neutral face men' and 'neutral face women'
subprocess.run(["gallery-dl", "--range", "1-500", "https://www.pinterest.co.uk/search/pins/?q=neutral%20face%20men&rs=typed"])
subprocess.run(["gallery-dl", "--range", "1-500", "https://www.pinterest.co.uk/f1nd1ngp4nd0ra/neutral-faces/"])



subprocess.run(["gallery-dl", "--range", "1-500", "https://www.pinterest.co.uk/search/pins/?q=neutral%20face%20women&rs=typed"])
#!gallery-dl https://www.pinterest.co.uk/bodiebodes/portraits/female-front/, https://www.pinterest.co.uk/asiavinae/neutral-front-faces/, https://www.pinterest.co.uk/f1nd1ngp4nd0ra/neutral-faces/, https://www.pinterest.co.uk/bodiebodes/portraits/male-front/
# Out:
# /Users/nixi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_41799102765241729.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_171207223309345284.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_9359111716234315.png
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_626352260690424423.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_32369691065333244.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_70437487926419.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_539376492887152868.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_42854633942832935.jpg
# ./gallery-dl/pinterest/Search/neutral face men/pinterest_68736853740.jpg
# ...

# %%
# Add to respective emotional class folder

#class_folder = 'neutral-face'
#source_directory = '/notebooks/AI-for-Media-project-23-24/gallery-dl' 
    
#target_directory = os.path.join(my_dataset_path, class_folder)
#file_names = os.listdir(source_directory)
    
#for file_name in file_names:
#    shutil.move(os.path.join(source_directory, file_name), target_directory)

# Check if files have been saved correctly
#os.listdir('/notebooks/AI-for-Media-project-23-24/my-classification-dataset/neutral-face')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/nixi/Desktop/Final thesis folder 24/AI-for-Media-project-23-24/1-Image-classification-dataset (1).ipynb Cell 9 line 5
#       <a href='vscode-notebook-cell:/Users/nixi/Desktop/Final%20thesis%20folder%2024/AI-for-Media-project-23-24/1-Image-classification-dataset%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> source_directory = '/notebooks/AI-for-Media-project-23-24/gallery-dl'
#       <a href='vscode-notebook-cell:/Users/nixi/Desktop/Final%20thesis%20folder%2024/AI-for-Media-project-23-24/1-Image-classification-dataset%20%281%29.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> class_folder = 'neutral-face'
# ...

# %% [markdown]
# #### Sad faces

# %%
# Populate the 'sad faces' class

source_directory = "/notebooks/AI-for-Media-project-23-24/my-classification-dataset/sad-faces"

#subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/briantenimmons/sad-faces/"])
#subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/jessesena1/sad-faces/"])
#subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/artg30rg3/sad-faces/"])
#subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/helenwyrich/sad-faces/"])
#subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/search/pins/?q=sad%20face&rs=typed"])
#subprocess.run(["gallery-dl", "-o", source_directory,"https://www.pinterest.co.uk/f1nd1ngp4nd0ra/sad-faces-23/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/daveblanch/face-sadness/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/snoglebod/crying/"])
# Out:
# /Users/nixi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506839079758.png
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506839079719.jpg
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506839079701.jpg
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506839079660.jpg
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506839079623.jpg
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506838737965.jpg
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506831793691.jpg
# ./gallery-dl/pinterest/daveblanch/Face - Sadness/pinterest_370491506828559130.jpg
# ...

# %%
# Add to respective folder

source_directory = '/notebooks/AI-for-Media-project-23-24/gallery-dl'
class_folder = 'sad-face'
target_directory = '/notebooks/AI-for-Media-project-23-24/my-classification-dataset/sad-face'

# If the target directory exists...
os.makedirs(target_directory, exist_ok=True)

# Move all files within directory into 'sad-face' emotional class.
file_names = os.listdir(source_directory)

for file_name in file_names:
    if file_name.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp' , '.psd')):
        shutil.move(os.path.join(source_directory, file_name), target_directory)

# %% [markdown]
# #### Angry faces

# %%
# Populate gallery-dl with 'angry-face' images

#source_directory = "/notebooks/AI-for-Media-project-23-24/my-classification-dataset/angry-faces"

subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/search/pins/?q=angry%20face&rs=typed"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/naomibiney/angry-faces/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/stvmrsdn/the-angry-face/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/zahirramailk/angry-faces/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/grzegorzluczka/angry-faces/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/search/pins/?q=angry&rs=typed"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/f1nd1ngp4nd0ra/angryface2024/"])
# Out:
# /Users/nixi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ./gallery-dl/pinterest/Search/angry face/pinterest_23432860570947376.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_141441244541518271.png
# ./gallery-dl/pinterest/Search/angry face/pinterest_3870349670708847.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_774124928831574.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_1125968645661951.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_720294534178879804.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_3166662229978328.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_5348093302693124.jpg
# ./gallery-dl/pinterest/Search/angry face/pinterest_170714642112677313.jpg
# ...

# %%
# Add to respective folder

#source_directory = '/notebooks/AI-for-Media-project-23-24/gallery-dl'
#target_directory = '/notebooks/AI-for-Media-project-23-24/my-classification-dataset/angry-face'
#class_folder = 'angry-face'

# If the target directory exists...

#os.makedirs(target_directory, exist_ok=True)
# Move all files within directory into 'sad-face' emotional class.
#file_names = os.listdir(source_directory)

#for file_name in file_names:
#    if file_name.endswith(('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp' , '.psd')):
#        shutil.move(os.path.join(source_directory, file_name), target_directory)

# %% [markdown]
# #### Happy faces

# %%
# Populate gallery-dl with 'happy-face' images

source_directory = "/notebooks/AI-for-Media-project-23-24/my-classification-dataset/sad-faces"

subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/katjavenneman/happy-faces/"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/diedraghicks/happy-face"])
subprocess.run(["gallery-dl", "-o", source_directory, "https://www.pinterest.co.uk/search/pins/?q=happy%20face&rs=typed"])
# Out:
# /Users/nixi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352446078739.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352446078693.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352446057719.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352446057633.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352445952631.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352445821492.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352445787729.jpg
# ./gallery-dl/pinterest/katjavenneman/Happy Faces/pinterest_348325352445718050.jpg
# ...

# %% [markdown]
# ### Understanding ratio of images for each emotional class
# Original ratio:
# - Neutral-face images: 45
# - Happy-face images: 285
# - Sad-face images: 219
# - Angry-face images: 156

# %%
# Find out the total images in each emotional class within my current directory

emotional_classes = ['neutral-face', 'happy-face', 'sad-face', 'angry-face', ]

dirrectory = "/Users/nixi/Desktop/Final-thesis-folder-24/AI-for-Media-project-23-24/my-classification-dataset"

#Instantiate for counts
class_counts = {}

for emotion in emotional_classes:
    class_dir = os.path.join(dirrectory, emotion)
    # Count the number of image files in the class directory
    class_counts[emotion] = len([file for file in os.listdir(class_dir) if file.endswith(('jpg', 'jpeg', 'png', 'gif', 'bmp'))])


# Print out the value of each folder
for emotion_class, count in class_counts.items():
    print(f"Emotional class: {emotion_class}, Total images: {count}")
    class_counts[emotion] = len([file for file in os.listdir(class_dir) if file.endswith(('jpg', 'jpeg', 'png', 'gif', 'bmp'))])
# Out:
# Emotional class: neutral-face, Total images: 1144
# Emotional class: happy-face, Total images: 2227
# Emotional class: sad-face, Total images: 1177
# Emotional class: angry-face, Total images: 1150
